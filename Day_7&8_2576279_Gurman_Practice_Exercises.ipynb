# %% [markdown]
# # 1. Write a Python program to find a target values in a list using linear search with following steps
#
# a. Initialize the list to store the input elements.
#
# b. Initialize found=False.
#
# C Enter the item to be searched (match_item).
#
# d. For each element in the list
#
# 1 if match_item = value
#
# a. return match_item's position.
#
# e. If the match_item is not in the list, display an error message that the item is not found in the list.

# %%
data=[]
n=int(input('Enter no of elements to be inserted:\t'))
for i in range(0,n):
    x=int(input('Enter the Element %d:'%(i+1)))
    data.append(x)

e=int(input('Enter the value to be searched: \t'))
pos=0
found=False
while pos <n and not found:
    if data[pos]==e:
        found=True
    else:
        pos+=1

if found:
    print('Element %d Found at Position %d'%(e,pos+1))

else:
    print('Element %d not found in the list'%e)

print(data)
# Out:
# Enter no of elements to be inserted:	5
# Enter the Element 1:2
# Enter the Element 2:6
# Enter the Element 3:3
# Enter the Element 4:5
# Enter the Element 5:1
# Enter the value to be searched: 	6
# Element 6 Found at Position 2
# [2, 6, 3, 5, 1]

# %% [markdown]
# # 2. Write a Python program to implement binary search to find the target values from the list:
#
# a. Create a separate function to do binary search.
#
# b. Get the number of inputs from the user
#
# c. Store the inputs individually in a list.
#
# d. In binary search function at first sort the list in order to start the search from middle of the list.
#
# e Compare the middle element to right and left elements to search target element
#
# f. If greater, move to right of list or else move to another side of the list.
#
# g. Print the result along with the position of the element.

# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    
    while left <= right:
        mid = (left + right) // 2
        mid_value = arr[mid]
        
        if mid_value == target:
            return f"Element {target} found at position {mid+1}"
        elif mid_value < target:
            left = mid + 1
        else:
            right = mid - 1
    
    return f"Element {target} not found in the list"

input_list = [int(x) for x in input("Enter a list of numbers separated by spaces: ").split()]
target_value = int(input("Enter the target value to search for: "))
result = binary_search(input_list, target_value)
print(result)
# Out:
# Enter a list of numbers separated by spaces: 1 2 3 4 5 6 7 8
# Enter the target value to search for: 3
# Element 3 found at position 3

# %% [markdown]
# # 3. Write a Python program for sorting a list of elements using selection sort algorithm:
#
# a. Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list.
#
# b. In the first iteration, find the smallest element in the unsorted list and place it in the sorte list.
#
# c. In the second iteration, find the smallest element in the unsorted list and place it in the correct position by comparing with the element in the sorted list.
#
# d. In the third iteration, again find the smallest element in the unsorted list and place it in the correct position by comparing with the elements in the sorted list.
#
# e. This process continues till the unsorted list becomes empty.
#
# f. Display the sorted list.

# %%
def selection_sort(arr):
    sorted_list = [] 
    while arr: 
        min_val = min(arr) 
        sorted_list.append(min_val)  #
        arr.remove(min_val) 

    return sorted_list


unsorted_list = [64, 25, 12, 22, 11]
sorted_list = selection_sort(unsorted_list)
print("Sorted List:", sorted_list)
# Out:
# Sorted List: [11, 12, 22, 25, 64]

# %% [markdown]
# # 4. Write a Python program for sorting a list of elements using insertion sort algorithm:
#
# a. Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list.
#
# b. In the first iteration, take the first element in the unsorted list and insert it in Sorted list.
#
# C. In the second iteration, take the second element in the given list and compare with the element in the sorted sub list and place it in the correct position.
#
# d. In the third iteration, take the third element in the given list and compare with the elements in the sorted sub list and place the elements in the correct position.
#
# e. This process continues until the last element is inserted in the sorted sub list.
#
# f. Display the sorted elements.

# %%
def insertion_sort(input_list):
    sorted_list = []
    
    for unsorted_element in input_list:
        if not sorted_list:
            sorted_list.append(unsorted_element)
        else:
            for i in range(len(sorted_list)):
                if unsorted_element < sorted_list[i]:
                    sorted_list.insert(i, unsorted_element)
                    break
            else:
                sorted_list.append(unsorted_element)
    
    return sorted_list

if __name__ == "__main__":
    input_list = [12, 11, 13, 5, 6]
    sorted_list = insertion_sort(input_list)
    print("Sorted list:", sorted_list)
# Out:
# Sorted list: [5, 6, 11, 12, 13]

# %% [markdown]
# # 5. Write a Python program that performs merge sort on a list of numbers:
#
# a. Divide: If the given array has zero or one element, return.
#
# 1. Otherwise
#
# ii. Divide the input list in to two halves each containing half of the elements. i.e. left half and right half.
#
# b. Conquer: Recursively sort the two lists (left half and right half).
#
# a. Call the merge sort on left half.
#
# b. Call the merge sort on right half.
#
# C. Combine: Combine the elements back in the input list by merging the two sorted lists into a sorted sequence.

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    merged = []
    left_idx, right_idx = 0, 0

    while left_idx < len(left_half) and right_idx < len(right_half):
        if left_half[left_idx] < right_half[right_idx]:
            merged.append(left_half[left_idx])
            left_idx += 1
        else:
            merged.append(right_half[right_idx])
            right_idx += 1

    merged.extend(left_half[left_idx:])
    merged.extend(right_half[right_idx:])

    return merged

def get_user_input():
    try:
        input_list = input("Enter a list of numbers separated by spaces: ")
        input_list = [int(x) for x in input_list.split()]
        return input_list
    except ValueError:
        print("Invalid input. Please enter a list of numbers.")
        return get_user_input()

if __name__ == "__main__":
    print("Welcome to Merge Sort!")
    
    input_list = get_user_input()
    sorted_list = merge_sort(input_list)
    
    print("Original array:", input_list)
    print("Sorted array:", sorted_list)
# Out:
# Welcome to Merge Sort!
# Enter a list of numbers separated by spaces: 44 66 55 52 1 77
# Original array: [44, 66, 55, 52, 1, 77]
# Sorted array: [1, 44, 52, 55, 66, 77]

# %% [markdown]
# # 6. Write a Python script to perform the following operations on a singly linked list
#
# a. Create a list
#
# b. Find the smallest element from the list
#
# C. Insert an element if it is not a duplicate element
#
# d. Display the elements in reverse order

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

# a. Create a list
def create_linked_list(elements):
    linked_list = LinkedList()
    for element in elements:
        linked_list.insert(element)
    return linked_list

# b. Find the smallest element from the list
def find_smallest_element(linked_list):
    if not linked_list.head:
        return None
    min_element = linked_list.head.data
    current = linked_list.head.next
    while current:
        if current.data < min_element:
            min_element = current.data
        current = current.next
    return min_element

# c. Insert an element if it is not a duplicate element
def insert_if_not_duplicate(linked_list, data):
    if not linked_list.head:
        linked_list.head = Node(data)
    else:
        current = linked_list.head
        while current.next:
            if current.data == data:
                return  
            current = current.next
        if current.data != data:
            current.next = Node(data)

# d. Display the elements in reverse order using enqueue and dequeue
def display_reverse(linked_list):
    queue = []
    current = linked_list.head
    while current:
        queue.insert(0, current.data)
        current = current.next
    for item in queue:
        print(item, end=" -> ")
    print("None")

if __name__ == "__main__":
    
    # a. Create a list
    elements = [5, 2, 8, 2, 1]
    linked_list = create_linked_list(elements)

    # b. Find the smallest element from the list
    smallest = find_smallest_element(linked_list)
    print("Smallest element:", smallest)

    # c. Insert an element if it is not a duplicate element
    insert_if_not_duplicate(linked_list, 3)
    insert_if_not_duplicate(linked_list, 10)
    insert_if_not_duplicate(linked_list, 2)  
    
    # d. Display the elements in reverse order using enqueue and dequeue
    display_reverse(linked_list)
# Out:
# Smallest element: 1
# 10 -> 3 -> 1 -> 2 -> 8 -> 2 -> 5 -> None

# %% [markdown]
# # 7.Write a python program to implement the various operations for Stack ADT
#
# i.) Push
#
# ii.) Pop
#
# iii.) Display.

# %%
class Stack:
    def __init__(self):
        self.items = []

    # i.) Push operation
    def push(self, item):
        self.items.append(item)

    # ii.) Pop operation
    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return "Stack is empty"

    # iii.) Display operation
    def display(self):
        if not self.is_empty():
            print("[", end="")
            for i in range(len(self.items) - 1):
                print(self.items[i], end=", ")
            print(self.items[-1], end="]\n")
        else:
            print("Stack is empty")

    def is_empty(self):
        return len(self.items) == 0

if __name__ == "__main__":
    
    stack_length = int(input("Enter the length of the stack: "))
    
    stack = Stack()

    print(f"Enter {stack_length} elements to push onto the stack:")
    for _ in range(stack_length):
        item = int(input())
        stack.push(item)

    print("Stack elements:")
    stack.display()

    popped_item = stack.pop()
    print("Popped item:", popped_item)

    print("Stack elements after popping:")
    stack.display()
# Out:
# Enter the length of the stack: 5
# Enter 5 elements to push onto the stack:
# 33
# 22
# 55
# 44
# 31
# Stack elements:
# [33, 22, 55, 44, 31]
# Popped item: 31
# Stack elements after popping:
# [33, 22, 55, 44]

# %% [markdown]
# # 8. Write a python script to implement the various operations for Queue ADT
#
# i.) Insert
#
# ii.) Delete
#
# iii.) Display

# %%
class Queue:
    def __init__(self):
        self.items = []

    def insert(self, item):
        self.items.append(item)

    def delete(self):
        if len(self.items) > 0:
            return self.items.pop(0)
        else:
            return "Queue is empty"

    def display(self):
        return self.items

if __name__ == "__main__":
    queue = Queue()

    while True:
        print("\nQueue Operations:")
        print("1. Insert")
        print("2. Delete")
        print("3. Display")
        print("4. Quit")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == '1':
            item = input("Enter the item to insert into the queue: ")
            queue.insert(item)
            print(f"{item} inserted into the queue.")
        elif choice == '2':
            deleted_item = queue.delete()
            print(f"Deleted item: {deleted_item}")
        elif choice == '3':
            queue_items = queue.display()
            print("Queue:", queue_items)
        elif choice == '4':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please select a valid option.")
# Out:
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter the item to insert into the queue: 44
# 44 inserted into the queue.
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter the item to insert into the queue: 33
# 33 inserted into the queue.
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Queue: ['44', '33']
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 2
# Deleted item: 44
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Queue: ['33']
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 4
# Exiting the program.

# %% [markdown]
# # 9 Write a program in python to convert the following infix expression to its postfix form using push and pop operations of a Stack
#
# a. A/B^C+D*E-F*G
#
# b. (B^2-4*A*C)^(1/2) (100)

# %%
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return None

    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            return None

    def is_empty(self):
        return len(self.items) == 0

def infix_to_postfix(expression):
    precedence = {'+':1, '-':1, '*':2, '/':2, '^':3}
    postfix = []
    operator_stack = Stack()

    for char in expression:
        if char.isalnum():  
            postfix.append(char)
        elif char == '(':  
            operator_stack.push(char)
        elif char == ')':  
            while not operator_stack.is_empty() and operator_stack.peek() != '(':
                postfix.append(operator_stack.pop())
            operator_stack.pop()  
        elif char in precedence:  
            while (not operator_stack.is_empty() and operator_stack.peek() != '(' and
                   precedence[char] <= precedence.get(operator_stack.peek(), 0)):
                postfix.append(operator_stack.pop())
            operator_stack.push(char)

    while not operator_stack.is_empty():
        postfix.append(operator_stack.pop())

    return ''.join(postfix)

# Test cases
if __name__ == "__main__":
    # a. Infix expression: A/B^C+D*E-F*G
    infix_a = "A/B^C+D*E-F*G"
    postfix_a = infix_to_postfix(infix_a)
    print("Postfix expression for a:", postfix_a)

    # b. Infix expression: (B^2-4*A*C)^(1/2) (100)
    infix_b = "(B^2-4*A*C)^(1/2) (100)"
    postfix_b = infix_to_postfix(infix_b)
    print("Postfix expression for b:", postfix_b)
# Out:
# Postfix expression for a: ABC^/DE*+FG*-
# Postfix expression for b: B2^4A*C*-12/100^
